# %% [markdown]
# # Tipi Algebrici (Record e Variant)

# %% [markdown]
# ## Definire nuovi tipi
#
# In OCaml è possibile definire *nuovi* tipi di dato usando il costrutto `type`
#
# Si tratta di dare un nuovo nome a un tipo già esistente. Ci è utile per dare nomi significativi a tipi complessi. Ad esempio, possiamo chiamare `data` il tipo `int*int*int`

# %%
type data = int*int*int ;;

# %% [markdown]
# Di fatto, abbiamo definito un alias per `int*int*int`...

# %%
let controlla_data (d:data) =
    match d with
    | gg,mm,aaaa -> gg>0 && gg<=31
                 && mm>0 && mm<=12
                 && aaaa>1900 && aaaa<=2030 ;;

# %%
let accoda_data (d:data) lis =
    if controlla_data(d) then d::lis else lis ;;

# %% [markdown]
# L'uso degli alias può rendere il codice più leggibile, soprattutto quando abbiamo a che fare con tipi molto complicati (ad esempio, tuple di tuple, ...). Se etichettiamo il parametro di una funzione con un alias, come in questi esempi, l'algoritmo di inferenza di tipi di OCaml lo utilizzerà rendendoci la descrizione del tipo inferito più comprensibile.

# %% [markdown]
# ## Tipi algebrici
#
# OCaml consente di *comporre* tipi di dato per creare nuovi tipi

# %% [markdown]
# Immaginiamo un tipo come un insieme di valori
#
# * `int` come l'insieme dei numeri interi,
# * `bool` come l'insieme {`true`,`false`},
# * ecc...

# %% [markdown]
# Le operazioni di costruzione di nuovi tipi in OCaml sono ispirate alle operazioni insiemistiche:
# * *prodotto cartesiano* ($\times$), a cui corrispondono le *tuple* e i *record*
# * *unione disgiunta* ($\biguplus$) (che è una *somma* di insiemi), a cui corrispondo i *variant*

# %% [markdown]
# ## Tipi prodotto: tuple e record
#
# Il prodotto cartesiano di due insiemi (ad esempio, $\mathbb{N} \times \mathbb{N}$) è un insieme di coppie.
#
# * $(7,4) \in \mathbb{N}\times \mathbb{N}$
#
# Allo stesso modo il prodotto di due tipi (ad esempio `int * int`) è un tipo di coppie
#
# * `(7,4) : int*int`
#
# Il discorso si estende a tuple di qualunque dimensione, come abbiamo già visto...

# %% [markdown]
# ## Record
#
# I record sono un modo più avanzato di definire tipi prodotto
#
# Un record è un insieme di tipi di dati.
# Ogni valore di un record contiene un valore preso da **ciascuno degli insiemi dei tipi**.
#
# I record sono simili a tuple, ma possiamo dare un nome agli elementi (detti *campi*).
# Le componenti di un record possono essere quindi identificate dai nomi, mentre nelle tuple possono esserlo solo grazie alla posizione.
#
# Il tipo di accesso richiesto (per nome o per posizione) può aiutare a scegliere se usare  record o tuple.
#
# Ricordiamo che liste sono più indicate quando il tipo degli oggetti è omogeneo e la lunghezza dei dati da rappresentare non è limitata.

# %% [markdown]
# Definiamo, ad esempio, un tipo record da usare per descrivere i punti nel piano cartesiano (cioè, in uno spazio bidimensionale). Ogni punto sarà descritto da una coordinata `x` e una coordinata `y` ambedue di tipo `float`.

# %%
type punto_2d = { x: float; y: float; } ;;

# %% [markdown]
# Definito il tipo di un record, possiamo creare valori di quel tipo

# %%
let p = { x = 3.; y = -4. } ;;

# %% [markdown]
# Un valore di tipo record può essere decomposto usando il *pattern matching*
#
# Ad esempio, calcoliamo il quadrante del piano cartesiano in cui ricade un punto dato

# %%
let quadrante {x = x_pos; y = y_pos } =
    match x_pos>=0.,y_pos>=0. with
    | true,true -> 1
    | false,true -> 2
    | false,false -> 3
    | true,false -> 4 ;;

quadrante {x=(-3.); y=2.};;

# %% [markdown]
# ![Quadranti](files/images/quadranti.png)

# %% [markdown]
# **ATTENZIONE:** Nell'esempio ci sono due pattern matching. Quello che decompone il record è implicito nel `let` e usa il pattern `{x = x_pos; y = y_pos }`

# %% [markdown]
# Infatti, analogamente a quanto accade per le tuple, anche con i record è possibile specificare un pattern direttamente nell'operazione `let`, in modo tale da destrutturare immediatamente il record nelle sue componenti.

# %% [markdown]
# Un po' più semplicemente, possiamo usare direttamente `x` e `y` come nomi di variabili

# %%
let quadrante {x; y} =
    match x>=0.,y>=0. with
    | true,true -> 1
    | false,true -> 2
    | false,false -> 3
    | true,false -> 4 ;;

# %% [markdown]
# Oppure possiamo accedere ai campi usando la *dot notation*: `p.x` e `p.y`

# %%
let quadrante p =
    match p.x>=0.,p.y>=0. with
    | true,true -> 1
    | false,true -> 2
    | false,false -> 3
    | true,false -> 4 ;;

# %% [markdown]
# La dot notation consente di usare più variabili di tipo record in modo semplice

# %%
let p = {x=3.; y=3.} ;;
let q = {x=6.; y=7.} ;;
p.x ;;

# %% [markdown]
# Esempio: Distanza tra due punti $(x_1,y_1)$ e $(x_2,y_2)$ nel piano ($d = \sqrt{(x_2-x_1)^2+(y_2-y_1)^2}$ )

# %%
let distanza p1 p2 =
    sqrt ( (p2.x -. p1.x)**2. +. (p2.y -. p1.y)**2. ) ;;

# %%
distanza p q ;;

# %% [markdown]
# Nella funzione `distanza` si è usata la funzione built-in `sqrt` che calcola la radice quadrata (già vista) e anche l'operatore `**` che calcola l'elevamento a potenza: dati `a` e `b` di tipo `float`, l'operazione `a**b` calcola `a` elevato alla `b`.

# %% [markdown]
# Quando si usano record con molti campi, le operazioni possono diventare verbose

# %%
type persona = {nome: string; cognome: string; eta: int; indirizzo: string; citta: string} ;;

# %%
let mario = {nome="Mario"; cognome="Rossi"; eta=45; indirizzo="Via Roma 10"; citta="Pisa"} ;;

# %% [markdown]
# **Copia di record**
#
# È previsto anche un costrutto per costruire un nuovo record a partire da un record già esistente.
#
# Si tratta del costrutto di *functional update* `with` che consente di definire una variabile in funzione di un'altra.
#
# Nel nuovo record:
# * i campi forniti dopo il with sono quelli che assumono valori diversi dal record di partenza, così come indicato dal functional update
# * gli altri campi (non specificati dopo il with) vengono invece direttamente copiati dal record di partenza

# %%
let bianca = { mario with nome = "Bianca"; eta=13 } ;;

# %% [markdown]
# **ATTENZIONE:** Stiamo sempre lavorando con strutture dati *immutabili*. Quindi, anche utilizzando la functional update, non stiamo modificando il record di partenza, ma stiamo costruendo un nuovo record con nuovi valori, distinto dal precedente (che rimane come era prima).

# %% [markdown]
# ## Nota: record VS oggetti
#
# I record assomigliano ai dizionari di JavaScript, e si potrebbe pensare che "assegnando" funzioni ai loro elementi quello che si ottiene siano oggetti (come accadrebbe in JavaScript).

# %%
type finto_oggetto = { n: int; update: int -> int } ;;

# %% [markdown]
# La differenza con gli oggetti è che *i record sono immutabili*
#
# * le variabili non rappresentano uno "stato interno"... (base dell'object-orientation)
#
# Inoltre, i campi funzione (metodi) *non possono accedere* agli altri campi (variabili d'istanza)

# %% [markdown]
# Ad esempio:

# %%
let obj = { n = 10; update = fun x -> x } ;;
obj.n = 11 ;;  (* non posso assegnare... *)

# %% [markdown]
# In questo esempio si è cercato di usare `=` per assegnare un nuovo valore al campo `n` del (finto) oggetto, come si farebbe in altri linguaggi. Qui chiaramente l'interprete ha risposto `false` in quanto l'operazione `=` è un confronto e con `obj.n = 11` non si è fatto altro che confrontare il valore di `n` con `11`.
#
# Vedremo più avanti che nella parte imperativa di OCaml esistono alcuni operatori di assegnamento, tra cui `<-`. Se proviamo a utilizzarlo in questo caso otteniamo come risposta perentoria che il campo del record è immutabile.

# %%
obj.n <- 11 ;;

# %% [markdown]
# Nell'esempio successivo, invece, vediamo che i campi funzione non possono accedere agli altri campi del record, come invece potrebbe fare un metodo di un (vero) oggetto.

# %%
let obj = { n = 10; update = fun x -> n + x } ;;

# %% [markdown]
# ## Tipi unione (o somma): variant
#
# Un tipo *Variant* è un tipo di dati che può assumere forme alternative: ogni valore di quel tipo può appartenere a **una sola** tra le alternative dichiarate.
#
# I tipi varianti sono talvolta chiamati tipi unioni o somma.
#
# L'unione disgiunta di due insiemi è... l'unione disgiunta di due insiemi!
#
# * $C = A \biguplus B$
# * $x \in C$ se e solo se $x \in A$ oppure $x \in B$
#
# L'unione di due tipi `t1` e `t2` è un nuovo tipo `t` che idealmente "include" tutti i valori di tipo `t1` e `t2`

# %% [markdown]
# Mentre in alcuni linguaggi (ad esempio, TypeScript) si possono unire direttamente due tipi, scrivendo ad esempio:
#
# ```
# TYPESCRIPT: type t = string | int
# ```
#
# l'operazione di unione prevista da OCaml prevede di *etichettare* i valori dei tipi da unire
#
# I *variant* permettono quindi di rappresentare - in modo sicuro dal punto di vista dei tipi - dati che possono assumere più forme diverse, dove ogni forma è contrassegnata da un'*etichetta* esplicita.
#
# La grande differenza tra variant e record o tuple è che:
# * un valore di un tipo **variant** rappresenta una **singola** opzione da un insieme di possibilità (si può associare alla parola *or*), mentre
# * un valore di tipo **tupla** o **record** contiene **tutti gli elementi** di un insieme di possibilità contemporaneamente (si può associare alla parola *and*)

# %% [markdown]
# Ogni costruttore di un tipo Variant serve a "impacchettare" un valore di un certo tipo, dandogli un’etichetta che ne indica la forma.
#
# Ad esempio, per unire i tipi `string` e `int`, dobbiamo scegliere due etichette (ad esempio, `Txt` e `Num`) e usarle in questo modo:

# %%
type numero_testo =
    | Txt of string
    | Num of int ;;

# %% [markdown]
# In sostanza, ogni riga della definizione corrisponde a un caso possibile di tipo di valore, ed è caratterizzato da un'etichetta distinta (detta *costruttore*):
#
# $\texttt{Costruttore of tipo}$
#
# **ATTENZIONE:** I costruttori devono necessariamente iniziare con la lettera maiuscola (per distinguerli dalle variabili)

# %% [markdown]
# Anche i valori del nuovo tipo dovranno essere etichettati nello stesso modo:

# %%
let x = Txt "34" ;;
let y = Num 26 ;;

# %% [markdown]
# Per usare un variant, si “analizza” quale costruttore contiene: dato un valore, è possibile  ricostruire a quale dei tipi appartenga, tra quelli che sono stati uniti, usando i costruttori nel pattern matching

# %%
match x with
| Txt s -> "testo"
| Num n -> "numero" ;;

# %% [markdown]
# L'utilizzo dei costruttori `Txt` e `Num` nei pattern fa innanzitutto capire all'interprete di OCaml che la variabile `x` ha tipo `numero_testo`. A questo punto i vari pattern consentiranno di fare cose diverse in funzione del costruttore trovato in `x`.
#
# In questo esempio, visto che `x` era associato al valore `Txt "34"`, il risultato ottenuto è la stringa`"testo"`.

# %% [markdown]
# Qualche esempio di funzione che usa il tipo `numero_testo`:

# %%
let int_of_nt x =
    match x with
    | Txt s -> int_of_string s
    | Num n -> n ;;
    
let string_of_nt x =
    match x with
    | Txt s -> s
    | Num n -> string_of_int n ;;
    
int_of_nt (Txt "4") ;;
string_of_nt (Num 4) ;;

# %% [markdown]
# Queste funzioni consentono semplicemente di estrarre una rappresentazione intera o testuale da un qualunque valore di tipo `numero_testo`, indipendentemente dal fatto che al suo interno sia usato il costruttore `Txt` seguito da una string, o il costruttore `Num` seguito da un numero.

# %% [markdown]
# Nella dichiarazione di un tipo unione, la parte `of <tipo>` è facoltativa
#
# * si possono definire casi che consistono solo del costruttore, senza dati associati
# * sono come i "singoletti" nell'insiemistica

# %% [markdown]
# Usando i soli costruttori, si possono definire *tipi enumerazione*
#
# * In molti linguaggi chiamati *enum*
#
# Ciascun costruttore è associato a un
# numero naturale, che viene utilizzato nella valutazione di espressioni

# %%
type giorno = Lun | Mar | Mer | Gio | Ven | Sab | Dom   ;;
# Out:
# type giorno = Lun | Mar | Mer | Gio | Ven | Sab | Dom

# %%
Gio ;;
# Out:
# - : giorno = Gio

# %%
let is_weekend g =
    match g with
    | Sab | Dom -> true
    | _ -> false ;;
        
Lun < Mar;;

# %% [markdown]
# Un esempio più complesso:
# * tipo `int` esteso con `NaN`, $+ \infty$ e $- \infty$

# %%
type int_ext =
    | Num of int
    | NaN
    | Plus_inf
    | Minus_inf ;;

# %% [markdown]
# In questo caso abbiamo combinato costruttori associati a un tipo (`Num of int`) con costruttori "singoletti" che descrivono casi particolari:
#
# * `NaN` (sta per *Not a Number*) è il "numero" che si ottiene da un'operazione tra interi che restituisce un risultato non definito... ad esempio, la divisione $\frac{0}{0}$.
# * `Plus_inf` rappresenta $+ \infty$
# * `Minus_inf` rappresenta $- \infty$

# %% [markdown]
# Definiamo un po' di operazioni aritmetiche sul nuovo tipo

# %%
let sum x y =
    match x,y with
    | NaN,_ | _,NaN -> NaN
    | Plus_inf,Minus_inf | Minus_inf,Plus_inf -> NaN
    | Plus_inf,_ | _,Plus_inf -> Plus_inf
    | Minus_inf,_ | _,Minus_inf -> Minus_inf
    | Num n1,Num n2 -> Num (n1+n2) ;;

# %% [markdown]
# La somma di due `int_ext` deve tenere conto che uno o entrambi gli operandi potrebbero essere `NaN`, `Plus_inf` o `Minus_inf`. Nella funzione `sum`, i casi del pattern matching sono ordinati in modo da gestire prima tutti questi casi particolari, e lasciare come ultima opzione il caso "standard" in cui i due operandi sono in realtà degli interi normali.

# %% [markdown]
# **ATTENZIONE:** nessun warning: il pattern matching è esaustivo
#
# * non abbiamo scordato casi!

# %% [markdown]
# Il controllo di esaustività dei pattern operato dal compilatore è utile per prevenire molti bug. È infatti impossibile scordarsi di considerare qualche caso (a meno di ignorare il warning che otterremmo). Inoltre, il controllo fa sì che ci venga anche segnalato se abbiamo inserito dei casi ridondanti, ossia due pattern che possono fare match con lo stesso valore. Anche questo è spesso sintomo di un errore di programmazione.

# %% [markdown]
# Ancora:

# %%
let div x y =
    match x,y with
    | NaN,_ | _,NaN -> NaN
    | Plus_inf,Plus_inf | Minus_inf,Minus_inf -> NaN
    | Plus_inf,Minus_inf | Minus_inf,Plus_inf -> NaN
    | Plus_inf,_ -> Plus_inf
    | Minus_inf,_ -> Minus_inf
    | _,Plus_inf | _,Minus_inf -> Num 0
    | Num 0,Num 0 -> NaN
    | Num n,Num 0 -> if n>0 then Plus_inf else Minus_inf 
    | Num n1,Num n2 -> Num (n1/n2) ;;

# %% [markdown]
# L'implementazione dell'operazione di divisione è più complicata e critica dell'implementazione della somma. I casi da considerare sono di più, e soprattutto la divisione è un'operazione che può generare `NaN`,`Plus_inf` e `Minus_inf` a partire da operandi interi "normali"

# %%
div (Num 3) (Num 0) ;;

# %% [markdown]
# $3/0$

# %%
sum (Num 5) (div (Num 3) (Plus_inf)) ;;

# %% [markdown]
# $5 + (3 \,/ \!+\!\infty)$

# %% [markdown]
# ### Tipi opzione e tipi polimorfi
#
# Possono esserci funzioni che di solito restituiscono un valore di tipo `t`, ma che a volte non restituiscono nulla. Ad esempio, si potrebbe voler definire una funzione `massimo` che restituisca il valore massimo di una lista, ma che cosa potrebbe restituire se applicata a una lista vuota `[]`?
#
# Un esempio di tipo variant molto utilizzato (e *built-in* in OCaml) è il tipo opzione
#
# * consente di specificare un valore che può essere assente
# * usa i costruttori `Some` e `None`, che rendono esplicita la presenza o assenza del dato

# %%
Some 4;;
# Out:
# - : int option = Some 4

# %%
None ;;
# Out:
# - : 'a option = None

# %% [markdown]
# È importante osservare il tipo di un valore di tipo opzione. Nel primo
# caso abbiamo `int option` (che in qualche modo significa
# intero opzionale), mentre nel secondo caso abbiamo
# `'a option` in quanto il costruttore `None` è lo stesso qualunque sia il tipo che stiamo estendendo.
#
# È lo stesso principio di funzionamento già visto per le liste. Ad esempio,
# la lista `[4]` ha tipo `int list`, mentre la lista
# vuota `[]` ha tipo `'a list`.

# %% [markdown]
# I tipi opzione consentono di definire funzioni che restituiscono `None` in casi particolari

# %%
let rec massimo lis =
    match lis with
    | [] -> None   
    | x::lis' ->  match massimo lis' with
                    | None -> Some x (* lis' è la lista vuota *)
                    | Some max -> if x>max then Some x
                                    else Some max ;;
# Out:
# val massimo : 'a list -> 'a option = <fun>

# %% [markdown]
# La funzione `massimo` è *polimorfa*, in quanto l'unica operazione che viene eseguita sugli elementi della lista che prende come parametro è l'operazione di confronto `>` (che si applica a valori di qualunque tipo ordinabile).
#
# Questa funzione restituisce `None` in caso di lista vuota, in quanto il massimo di una lista priva di elementi non è definito.
#
# Nel caso il risultato sia `Some n` posso estrarre `n` usando il pattern matching.

# %%
massimo [3;4;2] ;;
massimo ["albero";"cane";"bambino"] ;;
massimo [] ;;
# Out:
# - : int option = Some 4
# - : string option = Some "cane"
# - : 'a option = None

# %% [markdown]
# È possibile accedere al contenuto di un valore opzionale e utilizzando il pattern matching

# %% [markdown]
# I tipi opzione sono (pre-)definiti in questo modo:

# %%
type 'a option =
    | Some of 'a
    | None ;;

# %% [markdown]
# questo esempio mostra come sia possibile definire *tipi polimorfi*
#
# * usando le variabili di tipo `'a`, `'b`, ...

# %% [markdown]
# Le variabili di tipo sono utilizzate come veri e propri parametri nella definizione del tipo (*polimorfismo parametrico*).

# %% [markdown]
# ## Tipi record e variant insieme
#
# Ovviamente, si possono creare tipi strutturati combinando a piacere record, variant, tuple, ecc...
#
# Mostriamo giusto un esempio, per completezza, di punto multidimensionale che può rappresentare un punto nel piano (2 dimensioni) o nello spazio (3 dimensioni) usando diversi costruttori.
# Un punto multidimensionale è rappresentato da due costruttori che contengono alcuni dati aggiuntivi, ovvero le coordinate del punto, in ognuno dei due casi,  raccolte in un record:

# %%
type punto_multidimensionale = 
    | DueDim of {x: float; y: float; }
    | TreDim of {x: float; y: float; z: float; }

# %%
let p1 = DueDim {x=10.; y=10.} ;;
let p2 = TreDim {x=4.; y=6.; z=8.} ;;

# %% [markdown]
# ## Tipi ricorsivi
# Un'importante generalizzazione dei tipi unione sono i *tipi ricorsivi*
#
# * sono tipi variant definiti in termini di sé stessi
#
# Servono per rappresentare strutture di dimensione potenzialmente infinita, come liste, alberi o espressioni aritmetiche.

# %% [markdown]
# Vediamoli usati per definire il tipo di una lista concatenata di interi
#
# **Attenzione**: OCaml ha già un tipo lista integrato, definito in modo del tutto analogo.
# Noi qui intendiamo ricostruirlo per capire la logica che ci sta dietro, definendo cosa è una lista e come funziona
#
# Cosa è una lista? Una lista di elementi è o vuota, o composta da un elemento e un’altra lista.

# %%
type lista_di_int =
    | Nil 
    | Elem of int * lista_di_int ;;
    
let lst = Elem (3 ,Elem (4, Elem (6,Nil))) ;;
# Out:
# type lista_di_int = Nil | Elem of int * lista_di_int
# val lst : lista_di_int = Elem (3, Elem (4, Elem (6, Nil)))

# %% [markdown]
# Una lista di interi è fatta di elementi di tipo `int` concatenati l'uno all'altro. Ogni elemento, quindi, deve prevedere anche un "riferimento" all'elemento successivo. L'ultimo elemento della lista avrà riferimento nullo (o meglio, a un elemento nullo), in quanto non esiste un successivo.
#
# Il tipo `lista_di_int` deve quindi essere il tipo di una qualunque lista di interi (indipendentemente dalla sua lunghezza). Per questo è definito ricorsivamente...
#
# Abbiamo due casi:
#
# * la lista è vuota: possiamo rappresentarla con un singolo elemento nullo che rappresenteremo con il costruttore `Nil`
# * la lista non è vuota: allora esiste un primo elemento (la testa) che rappresenteremo con il costruttore `Elem`. Tale elemento prevederà un intero e un riferimento all'elemento successivo. L'elemento successivo, però, altri non è che il primo elemento di un'altra lista: la lista di tutti gli elementi che seguono l'elemento corrente. Quindi possiamo vedere il riferimento al prossimo elemento come un riferimento a un'altra lista dello stesso tipo di quella che stiamo descrivendo. Per questo motivo al costruttore `Elem` è associato il tipo `int * lista_di_int`.
#
# In un valore di tipo `lista_di_interi` in realtà non abbiamo dei veri e propri riferimenti tra gli elementi. Dal momento che la ricorsione è usata all'interno di una coppia `int * lista_di_int`, la concatenazione degli elementi sarà realizzata tramite *annidamento* di coppie, come negli esempi mostrati sopra.

# %% [markdown]
# Ora possiamo definire una funzione che corrisponde all'operatore di concatenazione `::` delle liste di OCaml

# %%
let cons x lis =
    Elem (x,lis) ;;

cons 5 lst;;
# Out:
# val cons : int -> lista_di_int -> lista_di_int = <fun>
# - : lista_di_int = Elem (5, Elem (3, Elem (4, Elem (6, Nil))))

# %% [markdown]
# E possiamo definire altre operazioni su `lista_di_int`, mediante analisi dei casi e ricorsione. Si noti la simmetria tra la definizione del tipo e quella di funzione.

# %%
let rec somma_lista lis = 
    match lis with
    | Nil -> 0
    | Elem (x,lis') -> x + somma_lista lis' ;;
    
somma_lista ( Elem (3 ,Elem (4, Elem (6,Nil))));;

# %% [markdown]
# Il tipo built-in `'a list`, in effetti, è un caso particolare di variant ricorsivo polimorfo

# %%
type 'a my_list =
   | Empty                       (* corrisponde a [] *)
   | Cons of 'a * 'a my_list ;;  (* corrisponde a _::_ *)
# Out:
# type 'a my_list = Empty | Cons of 'a * 'a my_list

# %% [markdown]
# Il tipo `'a my_list` qui presentato è una re-implementazione del tipo `'a list` di OCaml. La mostriamo solo per far vedere che `'a list` è effettivamente a tutti gli effetti un tipo variant ricorsivo polimorfo.
# Si tratta di una struttura di dati i cui tipi dipendono da variabili di tipo, per poter creare liste di qualsiasi tipo di valore, non solo di numeri interi.
# Ci consente in questo modo, di creare una famiglia di tipi di dati correlati.

# %%
Empty ;;
Cons (3, Cons (4, Cons (1,Empty))) ;; (* corrisponde a 3::4::1 *)
Cons ("a", Cons ("b",Empty)) ;;       (* corrisponde a "a"::"b"::[] *)
# Out:
# - : 'a my_list = Empty
# - : int my_list = Cons (3, Cons (4, Cons (1, Empty)))
# - : string my_list = Cons ("a", Cons ("b", Empty))

# %% [markdown]
# Per semplificare la lettura, OCaml usa una sintassi *ad hoc* per i valori di tipo `'a list`, che conosciamo bene: `[x1;x2;...]`

# %% [markdown]
# ### Tipi ricorsivi e... Alberi
# Grazie ai tipi ricorsivi è semplice definire anche strutture non lineari come gli alberi, non predefiniti in OCaml

# %% [markdown]
# L'idea è esattamente quella già illustrata nell'esempio precedente delle liste di interi. Descriviamo, ad esempio, il tipo degli alberi binari con valori interi, `albero_bin`. Andiamo a descrivere le varie tipologie di elementi (in questo caso nodi intermedi o foglie) tramite costruttori diversi, e nel caso dei nodi intermedi (che sono collegati a sottoalberi) andiamo a riferirci ricorsivamente al tipo `albero_bin`.
#
# L'unica differenza essenziale con le liste viste prima è che `Elem` si applica a una sottolista, mentre `Nodo` si applica a due sottoalberi.

# %%
type albero_bin = 
  | Nodo of int*albero_bin*albero_bin 
  | Foglia of int ;;
# Out:
# type albero_bin = Nodo of int * albero_bin * albero_bin | Foglia of int

# %% [markdown]
# La ricorsione sui tipi non descrive quindi solo quanto lunga può essere una struttura, ma anche come si organizza internamente.
#
# Nelle liste, la ricorsione è una sequenza; negli alberi, è una gerarchia.
# In entrambi i casi, però, l’idea chiave è sempre la stessa: un costruttore che “chiude” il caso base (foglia o lista vuota) e un costruttore che “riapre” la ricorsione (nodo o elemento seguito dal resto).

# %% [markdown]
# Definiamo un valore di tipo `albero_bin` un passo alla volta... dalle foglie alla radice:

# %%
(* il codice di seguito costruisce questo albero:
         5
       /   \
      2     8
     / \   
    4  6 
*)

let n1 = Foglia 4 ;;
let n2 = Foglia 6 ;;
let n3 = Nodo (2,n1,n2) ;;
let n4 = Foglia 8 ;;
let n5 = Nodo (5,n3,n4) ;;
# Out:
# val n1 : albero_bin = Foglia 4
# val n2 : albero_bin = Foglia 6
# val n3 : albero_bin = Nodo (2, Foglia 4, Foglia 6)
# val n4 : albero_bin = Foglia 8
# val n5 : albero_bin = Nodo (5, Nodo (2, Foglia 4, Foglia 6), Foglia 8)

# %% [markdown]
# Vediamo alcune operazioni su alberi. La prima funzione implementa una visita anticipata dell'albero, mentre la seconda calcola la somma di tutti i valori contenuti nell'albero.
#
# **Visita anticipata**:
# * si analizza la radice,
# * poi si effettua la visita anticipata del sottoalbero sinistro, e infine
# * si effettua la visita anticipata del sottoalbero destro
#
# Questo tipo di visita, applicato all'albero genealogico, corrisponde all'antichissimo algoritmo usato per determinare l'ordine di successione al titolo in una famiglia nobile o regale.

# %% [markdown]
# * Nella **visita simmetrica** si visita il sottoalbero sinistro, quindi si esamina la radice e infine si visita il sottoalbero destro.
#
# * Nella **visita posticipata** si visitano prima il sottoalbero sinistro poi quello destro e infine si esamina la radice.

# %%
let rec visita_ant a =
    match a with
    | Foglia v -> [v]
    | Nodo (v,sx,dx) -> v::((visita_ant sx)@(visita_ant dx)) ;;
    
visita_ant n5 ;;
# Out:
# val visita_ant : albero_bin -> int list = <fun>
# - : int list = [5; 2; 4; 6; 8]

# %%
let rec somma_albero a =
    match a with
    | Foglia v -> v
    | Nodo (v,sx,dx) -> v + somma_albero sx + somma_albero dx ;;
    
somma_albero n5 ;;

# %% [markdown]
# ### Tipi ricorsivi e... Abstract Syntax Tree (AST)
#
# I tipi ricorsivi sono uno strumento per modellare linguaggi. Permettono infatti di modellare strutture più astratte e simboliche, come gli alberi di sintassi astratta

# %% [markdown]
# ### Alberi di sintassi astratta o Abstract Syntax Tree (AST)

# %% [markdown]
# Tipo di albero utile per questo corso
#
# Risultato del *parsing* (*analisi sintattica*) di un linguaggio formale:
# * rappresentano la struttura sintattica di un programma/espressione/termine appartenente a un certo linguaggio
# * linguaggio definito tramite una grammatica (ad esempio, formato BNF)

# %% [markdown]
# In JavaScript:
#
# ```
# C::= ... | if (E) C [else C] | ...
# ```
#
# ```
# if (x>y) max=x else max=y
# ```
#
# ![Quadranti](files/images/if-ast.png)

# %% [markdown]
# Esempio: le espressioni aritmetiche (su interi)
#
# ```
# Exp ::= n | Exp op Exp | -Exp | (Exp)
# op ::= + | - | * | / | %
# ```

# %% [markdown]
# La rappresentazione di un programma come albero di sintassi astratta si basa sulla definizione di un tipo variant, in cui
# * ogni **costruttore** corrisponde a una **produzione (caso) della grammatica** del linguaggio in formato BNF.
#
# Possiamo non rappresentare le parentesi: le parentesi servono infatti solo per capire quale operatore si applichi per primo, e questo viene rappresentato dalla posizione dei corrispondenti nodi nell'albero: l’ordine delle operazioni è implicito nella gerarchia tra i nodi.

# %% [markdown]
# La grammatica delle espressioni ha la stessa struttura delle seguenti dichiarazioni di tipo:

# %%
type op = Add | Sub | Mul | Div | Mod ;;
type exp =
    | Val of int
    | Op of op*exp*exp
    | UMin of exp ;;
# Out:
# type op = Add | Sub | Mul | Div | Mod
# type exp = Val of int | Op of op * exp * exp | UMin of exp

# %% [markdown]
# Ogni costruttore è associato a un tipo che rappresenta le informazioni espresse dalla corrispondente produzione nella grammatica. Ad esempio, il costruttore `Val`, che rappresenta la produzione `Exp ::= n` è associato al tipo `int` (per poter memorizzare `n`), mentre il costruttore `Op`, che rappresenta la produzione `Exp ::= Exp op Exp`, è associato al tipo `op*exp*exp` in modo da poter memorizzare il simbolo dell'operatore e le due espressioni a cui tale operatore si applica (che sono quindi sottoalberi dell'AST).

# %% [markdown]
# Sintassi astratta:
#
# ```
# 3 * 7 - 5
# ```

# %%
(* l'AST corrispondente all'espressione seguente è:
         -
       /   \
      *     5
     / \   
    3  7 
*)

let exp1 = Op (Sub, (Op (Mul, Val 3, Val 7)), Val 5) ;;
# Out:
# val exp1 : exp = Op (Sub, Op (Mul, Val 3, Val 7), Val 5)

# %% [markdown]
# ```
# -3 * (7-5)
# ```

# %%
(* l'AST corrispondente all'espressione seguente è invece:
         *
       /   \
      -    -
      |   /  \   
      3  7    5
*)

let exp2 = Op (Mul, UMin (Val 3), (Op (Sub, Val 7, Val 5))) ;;
# Out:
# val exp2 : exp = Op (Mul, UMin (Val 3), Op (Sub, Val 7, Val 5))

# %% [markdown]
# Per fare un paio di esempi di uso degli AST rappresentati come tipi algebrici in OCaml, vediamo una funzione che trasforma l'AST di un'espressione in una stringa, e una funzione che calcola il risultato di (valuta) un'espressione.

# %% [markdown]
# Rappresentazione come stringa:

# %%
let symbol o =
    match o with
    | Add -> "+" | Sub -> "-" | Mul -> "*" | Div -> "/" | Mod -> "%" ;;
let rec to_string e =
    match e with
    | Val n -> string_of_int n
    | Op (o,e1,e2) -> "("^ (to_string e1) ^ (symbol o) ^ (to_string e2) ^")"
    | UMin e' -> "(-"^(to_string e')^")" ;;
# Out:
# val symbol : op -> string = <fun>
# val to_string : exp -> string = <fun>

# %%
to_string exp1 ;;
to_string exp2 ;;
# Out:
# - : string = "((3*7)-5)"
# - : string = "((-3)*(7-5))"

# %% [markdown]
# Valutazione delle espressioni:

# %%
let rec eval e =
    match e with
    | Val n -> n
    | Op (o,e1,e2) -> 
        (match o with
        | Add -> (eval e1) + (eval e2)
        | Sub -> (eval e1) - (eval e2)
        | Mul -> (eval e1) * (eval e2)
        | Div -> (eval e1) / (eval e2)
        | Mod -> (eval e1) mod (eval e2)
        )
    | UMin e' -> - (eval e') ;;
# Out:
# val eval : exp -> int = <fun>

# %%
eval exp1 ;;
eval exp2 ;;
# Out:
# - : int = 16
# - : int = -6

# %% [markdown]
# Quello che abbiamo fatto con le espressioni aritmetiche è, in piccolo, esattamente ciò che fa un interprete.
