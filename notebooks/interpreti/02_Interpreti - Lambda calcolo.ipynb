# %% [markdown]
# # Un interprete del $\lambda$-calcolo
#
# Ora esamineremo passo dopo passo come realizzare un interprete completo per il $\lambda$-calcolo
# (che non valuta “operazioni aritmetiche”, ma applica funzioni a argomenti)

# %% [markdown]
# ## La sintassi del $\lambda$-calcolo
#
# $$
# e ::= x \mid \lambda x.e \mid e \, e
# $$
#
# Definiamo il tipo degli identificatori e dell'AST delle espressioni:

# %%
type id = string

type exp =
    Var of id
  | Lam of id * exp
  | App of exp * exp
# Out:
# type id = string
# type exp = Var of id | Lam of id * exp | App of exp * exp

# %% [markdown]
# Come sempre, per la sintassi si usano i tipi Unione o Variant (tipo di dati che può assumere forme alternative)
#
# + I variant permettono quindi di rappresentare - in modo sicuro dal punto di vista dei tipi - dati che possono assumere più forme diverse, dove ogni forma è contrassegnata da un'etichetta esplicita
#
# * Per usare un variant, si “analizza” quale costruttore contiene: dato un valore, è possibile ricostruire a quale dei tipi appartenga, tra quelli che sono stati uniti, usando i costruttori nel *pattern matching*
#
# Nella dichiarazione di un tipo unione, si anche possono definire casi che consistono solo del costruttore, senza dati associati (la parte `of <tipo>` è facoltativa)

# %% [markdown]
# Usare `id` serve a distinguere i nomi di variabile dal resto delle espressioni. Le variabili nel $\lambda$-calcolo sono nomi, non valori: rappresentano un identificatore che può essere legato a un valore o a un’espressione, ma di per sé non è un valore.

# %% [markdown]
# ## La semantica del $\lambda$-calcolo ($\beta$-riduzione standard)
#
# $$
# (\lambda x . e_1) e_2 \rightarrow e_1 \{ x := e_2 \}
# $$
#
# $$
# \frac{e_1 \rightarrow e_1'}{e_1 \, e_2 \rightarrow e_1' \, e_2}
# \qquad
# \frac{e_2 \rightarrow e_2'}{e_1 \, e_2 \rightarrow e_1 \, e_2'}
# $$
#
# $$
# \frac{e \rightarrow e'}{\lambda x . e \rightarrow \lambda x . e'}
# $$

# %% [markdown]
# ## Implementazione della capture-avoiding substitution
#
# Richiamo della definizione della sostituzione che evita catture di nomi:
#
# $$
# \begin{array}{rcl}
# x \{ x:= e \} & \equiv & e\\
# y \{ x:= e \} & \equiv & y \mbox{ se } y \neq x\\
# (e_1 e_2) \{ x:= e \} & \equiv & ( e_1 \{ x:= e \} ) ( e_2 \{ x:= e \} )\\
# (\lambda x . e_1) \{ x:= e \}& \equiv & (\lambda x . e_1) \\
# (\lambda y . e_1) \{ x:= e \} & \equiv & \lambda y . (e_1 \{ x:= e \}) \\
# & & \color{blue}{\mbox{ se } y \neq x \mbox{ e } y \not\in FV(e)}\\
# (\lambda y . e_1) \{ x:= e \} & \equiv & \lambda z . ((e_1 \{ y:= z \}) \{ x:= e \})\\
# & & \color{blue}{\mbox{ se } y \neq x \mbox{ e } \mathbf{y \in FV(e)} \mbox{ e } z \mbox{ fresca}}
# \end{array}
# $$

# %% [markdown]
# ## Implementazione di FV(e)
# Per la definizione della sostituzione è necessaria la definizione delle variabili libere (*Free Variables*) di un'espressione
#
# $$
# \begin{array}{c}
# FV(x) = \{x\}
# \\
# FV(\lambda x.e) = FV(e) \setminus \{x\}
# \\
# FV(e_1\,e_2) = FV(e_1)\cup FV(e_2)
# \end{array}
# $$
#
# Funzione che calcola ricorsivamente l'insieme delle *variabili libere* dell'espressione $e$ rappresentato come lista di identificatori:

# %%
(* calcola le variabili libere (non legate) in e *)
let rec fvs e =
  match e with
      Var x -> [x]
    | Lam (x,e) -> List.filter (fun y -> x <> y) (fvs e)
    | App (e1,e2) -> (fvs e1) @ (fvs e2)
;;
# Out:
# val fvs : exp -> id list = <fun>

# %% [markdown]
# Esempi d'uso:

# %%
(* TEST *)
(*
x, lambda x . y, lambda x . x, (lambda x . z) y
*)
fvs (Var "x") = ["x"];;
fvs (Lam ("x",Var "y")) = ["y"];;
fvs (Lam ("x",Var "x")) = [];;
fvs (App (Lam ("x", Var "z"), Var "y")) = ["z"; "y"];;
# Out:
# - : bool = true
# - : bool = true
# - : bool = true
# - : bool = true

# %% [markdown]
# ## Generatore di identificatori "freschi"
#
# La *capture avoiding substitution* richiede in alcuni casi di generare identificatori *freschi* (nuovi, non già presenti nell'espressione)

# %%
(* genera una variabile fresca *)
let newvar =
  let x = ref 0 in
  fun () -> 
    let c = !x in
    incr x;
    "v"^(string_of_int c)
# Out:
# val newvar : unit -> string = <fun>

# %% [markdown]
# `newvar` è una funzione senza parametri con una *variabile modificabile* `x` nella sua *chiusura*!

# %% [markdown]
# Esempi d'uso:

# %%
(* TEST *)
newvar ();;
newvar ();;
# Out:
# - : string = "v0"
# - : string = "v1"

# %% [markdown]
# Ora siamo pronti per implementare la capture-avoiding substitution:
#
# $$
# \begin{array}{rcl}
# ...
# \\
# (\lambda y . e_1) \{ x:= e \} & \equiv & \lambda y . (e_1 \{ x:= e \}) \\
# & & \color{blue}{\mbox{ se } y \neq x \mbox{ e } y \not\in FV(e)}\\
# (\lambda y . e_1) \{ x:= e \} & \equiv & \lambda z . ((e_1 \{ y:= z \}) \{ x:= e \})\\
# & & \color{blue}{\mbox{ se } y \neq x \mbox{ e } \mathbf{y \in FV(e)} \mbox{ e } z \mbox{ fresca}}
# \end{array}
# $$

# %%
(* sostituzione: subst e x m significa 
  "sostituisci le occurrenze della variabile x con m nell'espressione e" *)
let rec subst e x m =
  match e with
      Var y -> 
    if x = y then m (* sostituisci y con m *)
    else e (* le variabili non corrispondono: lascia x immutato *)
    | App (e1,e2) -> App (subst e1 x m, subst e2 x m)
    | Lam (y,e) ->
      if x = y then (* non sostituire sotto il binder *)
        Lam(y,e)
      else if not (List.mem y (fvs m)) then 
        (* non serve alpha convertire (y non è una variabile libera di e) *)
        Lam (y, subst e x m)
      else (* serve alpha convertire (y è è una variabile libera di e) *)
        let z = newvar() in (* si assume sia "fresca" *)
        let e' = subst e y (Var z) in (* sostituisci y con z in e *)
        Lam (z,subst e' x m) (* sostituire x nel termine modificato, e' *)
# Out:
# val subst : exp -> id -> exp -> exp = <fun>

# %%
(* TEST *)
let m1 =  (App (Var "x", Var "y"));;  (* x y *)
let m2 = (App (Lam ("z",Var "z"), Var "w"));; (* (lambda z . z) w *)
let m3 = (App (Lam ("z",Var "x"), Var "w"));; (* (lambda z . x)  w *)
let m4 = (App (App (Lam ("z",Var "z"), Lam ("x", Var "x")), Var "w"))
          (* (lambda z . z) (lambda x . x) w *)
            
let m1_zforx = subst m1 "x" (Var "z");; (* x y {x=z} *)
let m1_m2fory = subst m1 "y" m2 (* x y {y=(lambda z . z) w} *)
let m2_ughforz = subst m2 "z" (Var "ugh") (*(lambda z . z) w {z= "ugh"} *)
let m3_zforx = subst m3 "x" (Var "z") (* ((lambda z . x) w) {x=z} *)
let m1_m3fory = subst m1 "y" m3 (* xy{y=((lambda z . x) w)} *)
# Out:
# val m1 : exp = App (Var "x", Var "y")
# val m2 : exp = App (Lam ("z", Var "z"), Var "w")
# val m3 : exp = App (Lam ("z", Var "x"), Var "w")
# val m4 : exp = App (App (Lam ("z", Var "z"), Lam ("x", Var "x")), Var "w")
# val m1_zforx : exp = App (Var "z", Var "y")
# val m1_m2fory : exp = App (Var "x", App (Lam ("z", Var "z"), Var "w"))
# val m2_ughforz : exp = App (Lam ("z", Var "z"), Var "w")
# val m3_zforx : exp = App (Lam ("v2", Var "z"), Var "w")
# val m1_m3fory : exp = App (Var "x", App (Lam ("z", Var "x"), Var "w"))

# %% [markdown]
# ## Implementazione della semantica
#
# $$
# \small
# (\lambda x . e_1) e_2 \rightarrow e_1 \{ x := e_2 \}
# $$
#
#
# $$
# \small
# \frac{e_1 \rightarrow e_1'}{e_1 \, e_2 \rightarrow e_1' \, e_2}
# \quad
# \frac{e_2 \rightarrow e_2'}{e_1 \, e_2 \rightarrow e_1 \, e_2'}
# \quad
# \frac{e \rightarrow e'}{\lambda x . e \rightarrow \lambda x . e'}
# $$
#
# È una semantica small-step

# %%
(* beta riduzione. *)
let rec reduce e =
  match e with
      App (Lam (x,e1), e2) -> subst e1 x e2 (* applicazione diretta della regola beta *)
    | App (e1,e2) -> 
      let e1' = reduce e1 in (* prova a ridurre un termine a sinistra (lhs) *)
      if e1'<>e1 then App(e1',e2)
      else App (e1,reduce e2) (* non ha funzionato; prova a destra (rhs) *)
    | Lam (x,e) -> Lam (x, reduce e) (* riduci sotto il lambda (!) *)
    | _ -> e (* nessuna opportunità di ridurre ulteriormente *)
# Out:
# val reduce : exp -> exp = <fun>

# %%
(* TEST *)
let m2red = reduce m2 ;; (* (lambda z . z) w *)
let m3red = reduce m3 ;; (* (lambda z . x) w *)
let m4red1 = reduce m4 ;; (* (lambda z . z) (lambda x . x) w *)
let m4red2 = reduce m4red1 ;; (* vedi sopra *)
let m13sred = reduce m1_m3fory ;; (* x ((lambda z . x) w) *)
# Out:
# val m2red : exp = Var "w"
# val m3red : exp = Var "x"
# val m4red1 : exp = App (Lam ("x", Var "x"), Var "w")
# val m4red2 : exp = Var "w"
# val m13sred : exp = App (Var "x", Var "x")

# %% [markdown]
# Notare la potenza del pattern matching all’opera: posso confrontare `e` con `App (Lam (x,e1), e2)`, entrando nella struttura interna dell’espressione e accedendo direttamente alle sue componenti.
# In un solo passaggio posso cioè:
#
# * verificare se il pattern corrisponde alla struttura dell’espressione, e
#
# * associare simultaneamente le variabili del pattern ai corrispondenti componenti dell’espressione.

# %% [markdown]
# *DOMANDA:* Ma la semantica che abbiamo implementato è effettivamente questa?
#
# $$
# (\lambda x . e_1) e_2 \rightarrow e_1 \{ x := e_2 \}
# $$
#
#
# $$
# \frac{e_1 \rightarrow e_1'}{e_1 \, e_2 \rightarrow e_1' \, e_2}
# \qquad
# \frac{e_2 \rightarrow e_2'}{e_1 \, e_2 \rightarrow e_1 \, e_2'}
# $$
#
# $$
# \frac{e \rightarrow e'}{\lambda x . e \rightarrow \lambda x . e'}
# $$

# %% [markdown]
# *Non esattamente...*
#
# * L'*ordine dei pattern* nel pattern matching *privilegia l'applicazione funzionale* alla riduzione di $e_1$ e di $e_2$
#
# ```
# match e with
#     | App (Lam (x,e1), e2) -> subst e1 x e2 (* direct beta rule *)
#     | App (e1,e2) -> ...
# ```
#
# * Inoltre, questo modo di gestire l'applicazione funzionale dice che `e2` può essere ridotto *solo se `e1` non è riducibile*:
#
# ```
# App (e1,e2) ->
#       let e1' = reduce e1 in (* try to reduce a term in the lhs *)
#       if e1'<>e1 then App(e1',e2)
#       else App (e1,reduce e2) (* did not work; try rhs *)
# ```

# %% [markdown]
# Quindi la semantica che abbiamo implementato in realtà è la seguente variante deterministica:
#
# $$
# (\lambda x . e_1) e_2 \rightarrow e_1 \{ x := e_2 \}
# $$
#
# $$
# \frac{e_1 \neq_{\alpha} \lambda x . e_3 \quad e_1 \rightarrow e_1'}{e_1 \, e_2 \rightarrow e_1' \, e_2}
# \qquad
# \frac{e_1 \neq_{\alpha} \lambda x . e_3 \quad e_1 \not\rightarrow \quad e_2 \rightarrow e_2'}{e_1 \, e_2 \rightarrow e_1 \, e_2'}
# $$
#
# $$
# \frac{e \rightarrow e'}{\lambda x . e \rightarrow \lambda x . e'}
# $$
#
# in cui:
#
# * $=_{\alpha}$ è l'$\alpha$-equivalenza
# * $e_1 \not\rightarrow$ significa $\not\exists e_1' . e_1 \rightarrow e_1'$

# %% [markdown]
# D'altra parte la definizione originale è *non deterministica*
#
# * la stessa espressione può portare a due riduzioni diverse
#
# Esempio:
#
# $$
# ((\lambda x.\,x)\,y)\;((\lambda x.\,x)\,y) \to
# \begin{cases}
# y\;((\lambda x.\,x)\,y)\\
# ((\lambda x.\,x)\,y)\;y
# \end{cases}
# $$
#
# Invece *l'interprete è un programma* e la sua esecuzione **deve** essere *deterministica*
#
# * si può dimostrare, sfruttando la proprietà di confluenza del $\lambda$-calcolo (cioè Church-Rosser) che nonostante le condizioni aggiunte non si perdono computazioni possibili

# %% [markdown]
# ## PER ESERCIZIO...
#
# * Implementare la *chiusura transitiva* della semantica, che consente di eseguire intere computazioni invece che singoli passi. Che succede se le diamo in pasto l'espressione $\Omega = (\lambda x . x x)(\lambda x . x x)$?
# * Implementare la semantica *call-by-value* del $\lambda$-calcolo, in cui la riduzione beta si applica solo se l’argomento è stato valutato completamente.
#
#
# $$
# (\lambda x . e_1) v \rightarrow e_1 \{ x := v \}
# $$
#
#
# $$
# \frac{e_1 \rightarrow e_1'}{e_1 \, e_2 \rightarrow e_1' \, e_2}
# \qquad
# \frac{e_2 \rightarrow e_2'}{v \, e_2 \rightarrow v \, e_2'}
# $$
#
# * Implementare la seguente *semantica big-step* del $\lambda$-calcolo e verificare che cosa succede dandole in pasto l'espressione $\Omega$:
#
# $$
#     \frac{e \rightarrow_{bs} e'}{\lambda x.e \rightarrow_{bs} \lambda x.e'}
# \qquad
#     x \rightarrow_{bs} x
# $$
#
# $$
#     \frac{e_1 \rightarrow_{bs} \lambda x.e_1' \quad e_2 \rightarrow_{bs} e_2' \quad e_1'\{x:=e_2'\} \rightarrow_{bs} e'}{e_1 \, e_2 \rightarrow_{bs} e'}
# $$

# %%
(* Funzione di chiusura transitiva della riduzione:
   compute e = e' tale che e →* e' ed e' è in forma normale
(cioè non ulteriormente riducibile)*)
let rec compute e =
  let e' = reduce e in               (* Esegui un passo di riduzione *)
  if e' = e then e                   (* Se il termine non cambia, è in forma normale *)
  else compute e'                    (* Altrimenti, continua a ridurre *)
  
let m4red1 = reduce m4 ;; (* (lambda z . z) (lambda x . x) w *)
let m4red1 = reduce (reduce m4) ;;
let m4red1'' = compute m4 ;; (* (lambda z . z) (lambda x . x) w *)
# Out:
# val compute : exp -> exp = <fun>
# val m4red1 : exp = App (Lam ("x", Var "x"), Var "w")
# val m4red1 : exp = Var "w"
# val m4red1'' : exp = Var "w"

# %%
(* semantica small-step call by_value *)
let rec reduce_cv e =
  match e with
    (* Caso di applicazione con funzione lambda a sinistra *)   
    | App (Lam (x, e1), e2) ->
        let e2' = reduce_cv e2 in       (* Riduci completamente l'argomento *)
        if e2' = e2 then subst e1 x e2  (* Applica la riduzione beta solo se e2 è un valore *)
        else App (Lam (x, e1), e2')     (* Altrimenti, continua a ridurre e2 *)
    (* Caso di applicazione generale *)
    | App (e1, e2) -> 
        let e1' = reduce_cv e1 in          (* Prova a ridurre e1 *)
        if e1' <> e1 then App (e1', e2) (* Se e1 è riducibile, aggiorna App (e1', e2) *)
        else App (e1, reduce_cv e2)        (* Altrimenti, riduci e2 *)  
    (* Caso di astrazione lambda *)    
    | Lam (x, e) -> Lam (x, e)          (* Nella call-by-value, non riduciamo sotto il lambda *)
    | _ -> e                            (* Nessuna opportunità di riduzione *)


let m3 = Lam ("x",App((Lam ("y",Var "y"),Var "z")));; (* (lambda z  . z) w *);;

reduce_cv m3;;

reduce m3;;
# Out:
# val reduce_cv : exp -> exp = <fun>
# val m3 : exp = Lam ("x", App (Lam ("y", Var "y"), Var "z"))
# - : exp = Lam ("x", App (Lam ("y", Var "y"), Var "z"))
# File "[30]", line 23, characters 0-6:
# 23 | reduce m3;;
#      ^^^^^^
# Error: Unbound value reduce

# %%
(* semantica big-step *)
let rec reduce_bs e =
  match e with
  | Var x -> Var x                            (* Regola: x -> x *)
  | Lam (x, e1) -> Lam (x, reduce_bs e1)      (* Regola: lambda x.e -> lambda x.e' *)
  | App (e1, e2) ->                           (* Regola dell'applicazione *)
      let e1' = reduce_bs e1 in
      (match e1' with
       | Lam (x, e1'') ->
           let e2' = reduce_bs e2 in
           reduce_bs (subst e1'' x e2')         (* Sostituzione e riduzione ricorsiva *)
       | _ -> App (e1', e2))        (* Se e1 non è una funzione, restituisce App(e1', e2) *)

let m3 = Lam ("x",App((Lam ("y",Var "y"),Var "z")));; (* (lambda z . z) w *);;

reduce_bs m3;;

# %%
(* Definizione di Omega *)
let omega = App (Lam ("x", App (Var "x", Var "x")), Lam ("x", App (Var "x", Var "x")))
(* Esecuzione: va in loop *)
let result = reduce_bs omega ;;

# %% [markdown]
# ## Funzioni di utilità per la stampa delle $\lambda$-espressioni

# %%
(* pretty printing *)
open Format;;

let ident = print_string;;
let kwd = print_string;;

let rec print_exp0 = function
  | Var s ->  ident s
  | lam -> open_hovbox 1; kwd "("; print_lambda lam; kwd ")"; close_box ()

and print_app = function
  | e -> open_hovbox 2; print_other_applications e; close_box ()

and print_other_applications f =
  match f with
  | App (f, arg) -> print_app f; print_space (); print_exp0 arg
  | f -> print_exp0 f

and print_lambda = function
  | Lam (s, lam) ->
      open_hovbox 1;
      kwd "\\"; ident s; kwd "."; print_space(); print_lambda lam;
      close_box()
  | e -> print_app e;;
# Out:
# val ident : string -> unit = <fun>
# val kwd : string -> unit = <fun>
# val print_exp0 : exp -> unit = <fun>
# val print_app : exp -> unit = <fun>
# val print_other_applications : exp -> unit = <fun>
# val print_lambda : exp -> unit = <fun>

# %%
(* TESTS *)
print_lambda m1; print_newline ();;
print_lambda m2; print_newline ();;
# Out:
# x y
# - : unit = ()
# (\z. z) w
# - : unit = ()
