# %% [markdown]
# # Un interprete di MiniCaml

# %% [markdown]
# Vediamo adesso come implementare in OCaml un ambiente minimale.
#
# La spiegazione completa sul linguaggio MiniCaml e sullo sviluppo, passo passo, di questo interprete si trova nel materiale didattico del corso (slides).

# %% [markdown]
# ## Definizioni di tipi di dato usati nell'interprete
#
# Tipi per la sintassi astratta del linguaggio: identificatori, tipi ed espressioni

# %%
(* Identificatori *)
type ide = string;;

(* Tipi *)
type tname = TInt | TBool | TString | TClosure | TRecClosure | TUnBound


(* Abstract Expressions = espressioni nella sintassi astratta,
compongono l'Albero di Sintassi Astratta *)
type exp =
| EInt of int
| CstTrue
| CstFalse
| EString of string
| Den of ide (* binding identificatori *)
(* Operatori binari da interi a interi *)
| Sum of exp * exp
| Diff of exp * exp
| Prod of exp * exp
| Div of exp * exp
(* Operatori da interi a booleani *)
| IsZero of exp
| Eq of exp * exp
| LessThan of exp*exp
| GreaterThan of exp*exp
(* Operatori su booleani *)
| And of exp*exp
| Or of exp*exp
| Not of exp
(* Controllo del flusso, funzioni *)
| IfThenElse of exp * exp * exp
| Let of ide * exp * exp
| Letrec of ide * ide * exp * exp (* nome funzione, parametro formale,
corpo funzione, corpo let *)
| Fun of ide * exp (* parametro formale, corpo funzione *)
| Apply of exp * exp
# Out:
# type ide = string
# type tname = TInt | TBool | TString | TClosure | TRecClosure | TUnBound
# type exp =
#     EInt of int
#   | CstTrue
#   | CstFalse
#   | EString of string
#   | Den of ide
#   | Sum of exp * exp
#   | Diff of exp * exp
#   | Prod of exp * exp
#   | Div of exp * exp
#   | IsZero of exp
#   | Eq of exp * exp
#   | LessThan of exp * exp
#   | GreaterThan of exp * exp
#   | And of exp * exp
#   | Or of exp * exp
#   | Not of exp
#   | IfThenElse of exp * exp * exp
#   | Let of ide * exp * exp
#   | Letrec of ide * ide * exp * exp
#   | Fun of ide * exp
#   | Apply of exp * exp

# %% [markdown]
# Come sempre, per la sintassi si usano i tipi Unione o Variant (tipo di dati che può assumere forme alternative)
#
# + I variant permettono quindi di rappresentare - in modo sicuro dal punto di vista dei tipi - dati che possono assumere più forme diverse, dove ogni forma è contrassegnata da un'etichetta esplicita
#
# * Per usare un variant, si “analizza” quale costruttore contiene: dato un valore, è possibile ricostruire a quale dei tipi appartenga, tra quelli che sono stati uniti, usando i costruttori nel *pattern matching*
#
# Nella dichiarazione di un tipo unione, si anche possono definire casi che consistono solo del costruttore, senza dati associati (la parte `of <tipo>` è facoltativa)

# %%
let e = Sum(EInt 3, Prod(EInt 5, EInt 2));;
# Out:
# val e : exp = Sum (EInt 3, Prod (EInt 5, EInt 2))

# %% [markdown]
# ## Ambiente e valori esprimibili
#
# Ambiente come tipo polimorfo:
#
# * L'ambiente (environment) associa identificatori a valori: è una collezione di *associazioni* o  *binding*.
# * L'implementazione più semplice (come nelle slides del corso) è tramite una lista di coppie (identificatore,valore) e una funzione `lookup` che fornisce il valore associato a un dato identificatore
# * Qui invece l'ambiente è implementato come una funzione vera e propria "aggiornabile" tramite la funzione `bind` (sotto)
# * L'ambiente è definito come tipo polimorfo per consentire la mutua ricorsione con la definizione del tipo dei *valori esprimibili*, `evT`, cioè quei valori che possono essere calcolati e restituiti durante la valutazione delle espressioni
# * Assumiamo di avere *scoping statico* (i riferimenti non locali dell’astrazione funzionale sono cioè risolti nell’ambiente di dichiarazione della funzione)
# ***[Sulle slide si trova anche l'implementazione dello *scoping dinamico*]***
#
#
# I *valori esprimibili* sono i valori che possono essere calcolati e restituiti durante la valutazione di espressioni

# %%
(* Ambiente polimorfo *)
type 't env = ide -> 't
(* ‘t sarà il tipo dei valori esprimibili *)
# Out:
# type 't env = ide -> 't

# %%
(* Evaluation types = tipi esprimibili *)
type evT = 
    | Int of int 
    | Bool of bool 
    | String of string 
    | Closure of ide * exp * evT env 
    (* nome parametro formale, corpo funzione dichiarata,
       ambiente al momento della dichiarazione *)
    | RecClosure of ide * ide * exp * evT env
    (* nome funzione, nome parametro formale, corpo funzione dichiarata,
       ambiente al momento della dichiarazione *)
    | UnBound (* valore speciale *)
# Out:
# type evT =
#     Int of int
#   | Bool of bool
#   | String of string
#   | Closure of ide * exp * evT env
#   | RecClosure of ide * ide * exp * evT env
#   | UnBound

# %% [markdown]
# La funzione `emptyenv` prende un identificatore (`x`) e restituisce il valore speciale `UnBound`, che indica che l'ambiente non ha alcun legame iniziale

# %%
(* Ambiente vuoto *)
let emptyenv = function x -> UnBound
# Out:
# val emptyenv : 'a -> evT = <fun>

# %% [markdown]
# La funzione `bind` aggiorna l’ambiente `s` associando un identificatore `x` a un valore `v`. In particolare, restituisce una nuova funzione (ambiente) che:
# * associa `x` al valore `v`
# * per ogni altro identificatore `i` diverso da `x`,
#      usa l'ambiente originale `s`

# %%
(* Aggiornamento ambiente s con binding (x,v) fra una stringa x e un valore primitivo v *)
let bind (s: evT env) (x: ide) (v: evT) = 
    function (i: ide) -> if (i = x) then v else (s i)
# Out:
# val bind : evT env -> ide -> evT -> ide -> evT = <fun>

# %% [markdown]
# ## Type Checking (dinamico)
#
# Nell’ambiente di un interprete, i valori devono includere anche un'informazione sul tipo per consentire il type checking dinamico
#
# La funzione `getType` prende un valore `x` di tipo `evT` e restituisce un valore di tipo `tname` che rappresenta il *descrittore di tipo* associato a `x`
#
# In altre parole, `getType` restituisce il tipo di un valore esprimibile (`evT`)

# %%
(* Funzione da evT a tname che associa a ogni valore il suo descrittore di tipo  *)
let getType (x: evT) : tname =
    match x with
    | Int(n) -> TInt
    | Bool(b) -> TBool
    | String(s) -> TString
    | Closure(i,e,en) -> TClosure
    | RecClosure(i,j,e,en) -> TRecClosure
    | UnBound -> TUnBound
# Out:
# val getType : evT -> tname = <fun>

# %%
getType (Int 42);;
# Out:
# - : tname = TInt

# %% [markdown]
# La funzione `typecheck` prende una coppia `(type, typeDescriptor)` in cui:
# * `type` è un valore di tipo `tname`, cioè il tipo atteso del valore
# * `typeDescriptor` è un valore di tipo `evT`, il valore esprimibile da verificare

# %%
(* Type-checking *)
let typecheck ((x, y) : (tname*evT)) = 
    match x with
    | TInt -> (match y with 
               | Int(u) -> true
               | _ -> false
               )
    | TBool -> (match y with 
                | Bool(u) -> true
                | _ -> false
                )
    | TString -> (match y with
                 | String(u) -> true
                 | _ -> false
                 )
    | TClosure -> (match y with
                   | Closure(i,e,n) -> true
                   | _ -> false
                   )
    | TRecClosure -> (match y with
                     | RecClosure(i,j,e,n) -> true
                     | _ -> false
                     )
    |TUnBound -> (match y with
                 | UnBound -> true
                 | _ -> false
                 )
# Out:
# val typecheck : tname * evT -> bool = <fun>

# %%
typecheck (TInt, Int(3));;
# Out:
# - : bool = true

# %% [markdown]
# ## Eccezione in caso di errori durante l'esecuzione

# %%
(* Errori a runtime *)
exception RuntimeError of string
# Out:
# exception RuntimeError of string

# %% [markdown]
# ## Operazioni primitive
# La valutazione delle operazioni primitive richiede il controllo di tipi sugli operandi.
#
# Le operazione sono implementate tramite una regola di valutazione di tipo *eager*:
# prima di applicare l’operatore, si valutano tutti gli operandi (sotto-espressioni):
# ad esempio, per valutare `IsZero (Sum (EInt(1), EInt(2)))` prima va valutato l'argomento `Sum (EInt(1), EInt(2)).`
#
# Le operazioni si applicano a valori già valutati

# %%
(* PRIMITIVE del linguaggio *)

(* Controlla se un numero è zero *)
let is_zero(x) = match (typecheck(TInt,x),x) with
    | (true, Int(v)) -> Bool(v = 0)
    | (_, _) -> raise ( RuntimeError "Wrong type")

(* Uguaglianza fra interi *)
let int_eq(x,y) =   
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v = w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Somma fra interi *)	   
let int_plus(x, y) = 
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v + w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Differenza fra interi *)
let int_sub(x, y) = 
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v - w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Prodotto fra interi *)
let int_times(x, y) =
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v * w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")
    
(* Divisione fra interi *)
let int_div(x, y) =
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> 
                    if w<>0 then Int(v / w)
                            else raise (RuntimeError "Division by zero")
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Operazioni di confronto *)
let less_than(x, y) = 
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v < w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let greater_than(x, y) = 
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v > w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Operazioni logiche *)
let bool_and(x,y) = 
    match (typecheck(TBool,x), typecheck(TBool,y), x, y) with
    | (true, true, Bool(v), Bool(w)) -> Bool(v && w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let bool_or(x,y) = 
    match (typecheck(TBool,x), typecheck(TBool,y), x, y) with
    | (true, true, Bool(v), Bool(w)) -> Bool(v || w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let bool_not(x) = 
    match (typecheck(TBool,x), x) with
    | (true, Bool(v)) -> Bool(not(v))
    | (_,_) -> raise ( RuntimeError "Wrong type");;
# Out:
# val is_zero : evT -> evT = <fun>
# val int_eq : evT * evT -> evT = <fun>
# val int_plus : evT * evT -> evT = <fun>
# val int_sub : evT * evT -> evT = <fun>
# val int_times : evT * evT -> evT = <fun>
# val int_div : evT * evT -> evT = <fun>
# val less_than : evT * evT -> evT = <fun>
# val greater_than : evT * evT -> evT = <fun>
# val bool_and : evT * evT -> evT = <fun>
# val bool_or : evT * evT -> evT = <fun>
# val bool_not : evT -> evT = <fun>

# %%
(* esempio di applicazione di una primitiva aritmetica *)
is_zero (Int 3);;
# Out:
# - : evT = Bool false

# %% [markdown]
# ## Interprete
#
# L’interprete valuta le espressioni del linguaggio seguendo le regole della semantica,
# e lo fa in modo *syntax-driven*:
# segue direttamente la struttura sintattica delle espressioni,
# applicando per ogni costrutto la regola semantica corrispondente.
#
# In pratica, ogni forma sintattica (cioè ogni costruttore dell’AST)
# corrisponde a un caso del pattern matching dell’interprete.

# %%
(* Interprete *)
let rec eval (e:exp) (s:evT env) : evT = 
    match e with
    | EInt(n) -> Int(n)
    | CstTrue -> Bool(true)
    | CstFalse -> Bool(false)
    | EString(s) -> String(s)
    
    (* Si valuta un identificatore cercandone il valore nell'ambiente s *)
    | Den(i) -> (s i)

    (* La valutazione delle operazioni di base segue una strategia eager:
       prima di applicare l’operatore, si valutano i sottoalberi *) 
    | Prod(e1,e2) -> int_times((eval e1 s), (eval e2 s))
    | Sum(e1, e2) -> int_plus((eval e1 s), (eval e2 s))
    | Diff(e1, e2) -> int_sub((eval e1 s), (eval e2 s))
    | Div(e1, e2) -> int_div((eval e1 s), (eval e2 s))

    | IsZero(e) -> is_zero (eval e s)
    | Eq(e1, e2) -> int_eq((eval e1 s), (eval e2 s))
    | LessThan(e1, e2) -> less_than((eval e1 s),(eval e2 s))
    | GreaterThan(e1, e2) -> greater_than((eval e1 s),(eval e2 s))

    | And(e1, e2) -> bool_and((eval e1 s),(eval e2 s))
    | Or(e1, e2) -> bool_or((eval e1 s),(eval e2 s))
    | Not(e) -> bool_not(eval e s)

    | IfThenElse(e1,e2,e3) -> 
    (* In questo caso la valutazione non segue una strategia eager: la valutazione 
       dei sottoalberi avviene in base alla valutazione della guardia *)
        let g = eval e1 s in 
            (match (typecheck(TBool,g),g) with
            |(true, Bool(true)) -> eval e2 s
            |(true, Bool(false)) -> eval e3 s
            |(_,_) -> raise ( RuntimeError "Wrong type")
            )
            
    | Let(i, e, ebody) -> eval ebody (bind s i (eval e s))
    
    | Fun(arg, ebody) -> Closure(arg,ebody,s)
    
    | Letrec(f, arg, fBody, letBody) ->
        let benv = bind (s) (f) (RecClosure(f, arg, fBody,s)) in
            eval letBody benv
            
    | Apply(eF, eArg) ->
        let fclosure = eval eF s in 
            (match fclosure with 
            | Closure(arg, fbody, fDecEnv) -> 
                let aVal = eval eArg s in 
                let aenv = bind fDecEnv arg aVal in 
                eval fbody aenv 
            | RecClosure(f, arg, fbody, fDecEnv) -> 
                let aVal = eval eArg s in
                let rEnv = bind fDecEnv f fclosure in
                let aenv = bind rEnv arg aVal in 
                eval fbody aenv
            | _ -> raise ( RuntimeError "Wrong type")
            )
# Out:
# val eval : exp -> evT env -> evT = <fun>

# %% [markdown]
# ## Un'occhiata alla semantica

# %% [markdown]
# **Costanti e identificatori**
# $$\small
# \frac{}{\Sigma \triangleright n \Rightarrow Int(n)} \qquad
# \frac{}{\Sigma \triangleright \text{true}  \Rightarrow Bool(true)} \qquad
# \frac{}{\Sigma \triangleright \text{false}  \Rightarrow Bool(false)} \qquad
# \frac{}{%
#   \Sigma \triangleright “s” \Rightarrow String(s)
# }\qquad
# \frac{}{\Sigma \triangleright \text{Den}(i)  \Rightarrow \Sigma(i)}
# $$
#
# **Operazioni aritmetiche**
#
# Op:= Prod | Sum | Diff | Div e op: = int_times | int_sum | int_sub | int_div
#
# $$
# \frac{%
#   \Sigma \triangleright e_1 \Rightarrow Int(n_1)
#   \qquad
#   \Sigma \triangleright e_2 \Rightarrow Int(n_2)
# }{%
#   \Sigma \triangleright \text{Op}(e_1,e_2) \Rightarrow Int(n_1 \ \text{op} \ n_2)
# }
# $$
#
# **Operazioni di confronto (relazionali) e logiche**
#
# Rop:= Eq | | LessThan | GreaterThan e rop: = int_eq | less_than | greater_than
#
# Bop:= And | Or e bop: = bool_and | bool_or
#
# $$
# \frac{%
#   \Sigma \triangleright e \Rightarrow Int(0)
# }{%
#   \Sigma \triangleright \text{IsZero}(e) \Rightarrow Bool(true)
# }
# \qquad
# \frac{%
#   \Sigma \triangleright e \Rightarrow Int(n) \quad n \neq 0
# }{%
#   \Sigma \triangleright \text{IsZero}(e) \Rightarrow Bool(false)
# }
# $$
#
# $$
# \frac{%
#   \Sigma \triangleright e_1 \Rightarrow Int(n_1)
#   \quad
#   \Sigma \triangleright e_2 \Rightarrow Int(n_2)
# }{%
#   \Sigma \triangleright \text{Rop}(e_1,e_2) \Rightarrow Int(n_1 \ \text{rop} \ n_2)
# }
# \qquad
# \frac{%
#   \Sigma \triangleright e_1 \Rightarrow Bool(b_1)
#   \quad
#   \Sigma \triangleright e_2 \Rightarrow Bool(b_2)
# }{%
#   \Sigma \triangleright \text{Bop}(e_1,e_2) \Rightarrow Bool(b_1 \ \text{bop} \ b_2)
# }
# \qquad
# \frac{%
#   \Sigma \triangleright e \Rightarrow Bool(b)
# }{%
#   \Sigma \triangleright \text{Not}(e) \Rightarrow Bool(\neg b)
# }
# $$
#
#
# **Condizionale**
#
# $$
# \frac{%
#   \Sigma \triangleright e_1 \Rightarrow Bool(true)
#   \qquad
#   \Sigma \triangleright e_2 \Rightarrow v_2
# }{%
#   \Sigma \triangleright \text{IfThenElse}(e_1,e_2,e_3) \Rightarrow v_2
# }
# \qquad
# \frac{%
#   \Sigma \triangleright e_1 \Rightarrow Bool(false)
#   \qquad
#   \Sigma \triangleright e_3 \Rightarrow v_3
# }{%
#   \Sigma \triangleright \text{IfThenElse}(e_1,e_2,e_3) \Rightarrow v_3
# }
# $$
#
# Si noti che
# * la valutazione delle operazioni di base segue una strategia eager: prima di applicare l’operatore, si valutano i sottoalberi.
# * la valutazione dell'`IfThenElse` invece non segue una strategia eager: la valutazione  dei sottoalberi avviene in base alla valutazione della guardia

# %% [markdown]
# **Let**
#
# `Let(i, e, ebody) -> eval ebody (bind s i (eval e s))`
#
# * si valuta `e` nell’ambiente corrente `s`
# * si estende `s` aggiungendo l’associazione `i = (eval e s)`
# * si valuta `ebody` (il corpo del blocco) nel nuovo ambiente
#
# La corrispondente regola semantica è
# $$
# \frac{%
#   \Sigma \triangleright e \Rightarrow v
#   \qquad
#   \Sigma[i = v] \triangleright e_{body} \Rightarrow v'
# }{%
#   \Sigma \triangleright \text{Let}(i,e,e_{body}) \Rightarrow v'
# }
# $$

# %% [markdown]
# **Astrazione funzionale**
#
# `Fun(arg, ebody) -> Closure(arg,ebody,s)`
#
# La valutazione dell’astrazione funzionale restituisce una chiusura che include:
# il nome del parametro formale `arg`
# il corpo della funzione dichiarata `ebody`
# l’ambiente al momento della dichiarazione `s`
#
# La chiusura ricorda i legami delle variabili presenti al momento della dichiarazione di funzione
#
#
# La corrispondente regola semantica è
# $$
# \frac{}{%
#   \Sigma \triangleright \text{Fun}(arg,e_{body}) \Rightarrow Closure(arg,e_{body},\Sigma)
# }
# $$

# %% [markdown]
# **Applicazione funzionale nel caso generale**
#
# ``| Apply(eF, eArg) ->
#         let fclosure = eval eF s in
#             (match fclosure with
#             | Closure(arg, fbody, fDecEnv) ->
#                 let aVal = eval eArg s in
#                 let aenv = bind fDecEnv arg aVal in
#                 eval fbody aenv
#                 ``
#
#
# * si calcola la chiusura `Closure(arg,fbody,fDecEnv)`, valutando l'espressione `eF`
# * si valuta l’espressione che corrisponde al parametro attuale `eArg`: è una *call-by-value*
# * si estende l’ambiente di dichiarazione della funzione `fDecEnv`, presente all'interno della chiusura, con il legame tra il parametro formale `arg` e il valore ottenuto `aVal`
# * si valuta il corpo della funzione `fbody` nell’ambiente così ottenuto
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
#   \Sigma \triangleright e_F \Rightarrow Closure(arg,f_{body},\Sigma_{fDecEnv})
#   \qquad
#   \Sigma \triangleright e_{Arg} \Rightarrow a_{Val}
#   \qquad
#   \Sigma_{fDecEnv}[arg = a_{Val}] \triangleright f_{body} \Rightarrow v
# }{%
#   \Sigma \triangleright \text{Apply}(e_F,e_{Arg}) \Rightarrow v
# }
# $$

# %% [markdown]
# **Applicazione funzionale caso funzioni del primo ordine**
#
# Nelle note è stata prima definita l'astrazione funzionale nel caso di funzioni del primo ordine, con sintassi astratta:
#
# `Apply of Den(“f”) * exp`
#
# La chiusura `Closure(arg,fbody,fDecEnv)` si recupera cercando la corrispondente associazione nell'ambiente `s`
#
# ``| Apply(Den(“f”), eArg) ->
#         let fclosure = s f in
#             (match fclosure with
#             | Closure(arg, fbody, fDecEnv) ->
#                 let aVal = eval eArg s in
#                 let aenv = bind fDecEnv arg aVal in
#                 eval fbody aenv
#             |  _ -> failwith("non functional value"))
#             | RecClusure ...
#   | Apply(_,_) -> failwith("Application: not first order function") ;;``
#
# La funzione deve essere stata dichiarata all’interno di un `Let`
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
#   \Sigma \triangleright Den(“f”) \Rightarrow Closure(arg,f_{body},\Sigma_{fDecEnv})
#   \qquad
#   \Sigma \triangleright e_{Arg} \Rightarrow a_{Val}
#   \qquad
#   \Sigma_{fDecEnv}[arg = a_{Val}] \triangleright f_{body} \Rightarrow v
# }{%
#   \Sigma \triangleright \text{Apply}(Den(“f”),e_{Arg}) \Rightarrow v
# }
# $$

# %% [markdown]
# **Dichiarazione di funzioni ricorsive (Letrec)**
#
# ``| Letrec(f, arg, fBody, letBody) ->
#         let benv = bind (s) (f) (RecClosure(f, arg, fBody,s)) in
#             eval letBody benv
#             ``
#
# * si estende l’ambiente corrente `s` con il binding che associa `f` alla chiusura ricorsiva `RecClosure(f,arg,fBody,s)` che contiene: il nome della funzione stessa `f`, il parametro formale `arg`, il corpo della funzione `fBody` e l'ambiente di dichiarazione `s` e si ottiene l'ambiente `benv`
# * si valuta il corpo del let `letBody`, cioè l'espressione da valutare con la funzione ricorsiva, dentro l'ambiente esteso
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
#   \Sigma[f = RecClosure(f,arg,f_{Body},\Sigma)]
#   \triangleright let_{Body} \Rightarrow v
# }{%
#   \Sigma \triangleright \text{Letrec}(f,arg,f_{Body},let_{Body}) \Rightarrow v
# }
# $$
#
# Estendendo l’ambiente con una chiusura ricorsiva
# che contiene già un riferimento al nome della funzione,
# la funzione può invocare sé stessa nel proprio corpo

# %% [markdown]
# **Applicazione di funzioni ricorsive**
#
# ``| Apply(eF, eArg) ->
#         let fclosure = eval eF s in
#             (match fclosure with
#             ...
#             | RecClosure(f, arg, fbody, fDecEnv) ->
#                 let aVal = eval eArg s in
#                 let rEnv = bind fDecEnv f fclosure in
#                 let aenv = bind rEnv arg aVal in
#                 eval fbody aenv ``
#
# * si estende l’ambiente corrente `s` con il binding che associa `f` alla chiusura ricorsiva `RecClosure(f,arg,fBody,s)` che contiene: il nome della funzione stessa `f`, il parametro formale `arg`, il corpo della funzione `fBody` e l'ambiente di dichiarazione `s`
# * si valuta il corpo del let (`letBody`), cioè l'espressione da valutare con la funzione ricorsiva, dentro l'ambiente esteso
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
# \begin{array}{c}
#   \Sigma \triangleright e_F \Rightarrow RecClosure(f,arg,f_{body},\Sigma_{fDecEnv})
#   \qquad
#   \Sigma \triangleright e_{Arg} \Rightarrow a_{Val}
#   \\
#   \Sigma_{fDecEnv}[f = RecClosure(f,arg,f_{body},\Sigma_{fDecEnv})][arg = a_{Val}] \triangleright f_{body} \Rightarrow v
#   \end{array}
# }{%
#   \Sigma \triangleright \text{Apply}(e_F,e_{Arg}) \Rightarrow v
# }
# $$

# %% [markdown]
# ## Esempio di esecuzione: fattoriale

# %%
let myRP = 
   Letrec("fact", "n",   
          IfThenElse(Eq(Den("n"),EInt(0)),
                     EInt(1),
                     Prod(Den("n"),
                          Apply(Den("fact"), 
                                Diff(Den("n"),EInt(1))))),                  
          Apply(Den("fact"),EInt(3)));;
# Out:
# val myRP : exp =
#   Letrec ("fact", "n",
#    IfThenElse (Eq (Den "n", EInt 0), EInt 1,
#     Prod (Den "n", Apply (Den "fact", Diff (Den "n", EInt 1)))),
#    Apply (Den "fact", EInt 3))

# %%
eval myRP emptyenv;;
# Out:
# - : evT = Int 6

# %% [markdown]
# ## Implementazione con scoping dinamico
#
# Nello scoping dinamico, il corpo della funzione viene valutato nell’ambiente ottenuto legando il parametro formale al valore del parametro attuale nell’*ambiente corrente*, cioè dove viene effettuata la chiamata
#
# Per gestirlo, dobbiamo estendere quanto fatto finora. Servono:
# * un nuovo tipo `TFun`
# * un nuovo tipo `fun = ide * exp`
# * un nuovo tipo esprimibile `Funval of efun` che `getType` associa a `TFun`
# * un nuova applicazione `Apply_sd`da usare nella nuova funzione di valutazione`eval_sd`
#
# Daremo solo i nuovi costrutti, tralasciando i casi delle funzioni ricorsive.

# %%
(* Sintassi astratta - scoping dinamico *)

(* Identificatori *)
type ide = string;;

(* Tipi *)
type tname = TInt | TBool | TString | TFun | TRecFun | TUnBound

(* Abstract Expressions = espressioni nella sintassi astratta,
compongono l'Albero di Sintassi Astratta *)
type exp =
| EInt of int
| CstTrue
| CstFalse
| EString of string
| Den of ide(* binding identificatori *)
(* Operatori binari da interi a interi *)
| Sum of exp * exp
| Diff of exp * exp
| Prod of exp * exp
| Div of exp * exp
(* Operatori da interi a booleani *)
| IsZero of exp
| Eq of exp * exp
| LessThan of exp*exp
| GreaterThan of exp*exp
(* Operatori su booleani *)
| And of exp*exp
| Or of exp*exp
| Not of exp
(* Controllo del flusso, funzioni *)
| IfThenElse of exp * exp * exp
| Let of ide * exp * exp
| Letrec of ide * ide * exp * exp (* nome funzione, parametro formale,
corpo funzione, corpo let *)
| Fun of ide * exp          (* definizione di funzione: parametro e corpo *) 
| Apply_sd of exp * exp      (* applicazione con scoping dinamico *)


(* Tipo delle funzioni con scoping dinamico: solo parametro e corpo *)
type efun = ide * exp

(* Valori esprimibili *)
type evT =
  | Int of int
  | Bool of bool
  | String of string 
  | UnBound
  | Funval of efun
  | RecFunval of ide * ide * exp
  
(* Ambiente *)
type 't env = ide -> 't

(* Ambiente vuoto *)
let emptyenv = function x -> UnBound

(* Aggiornamento ambiente s con binding (x,v) fra una stringa x e un valore primitivo v *)
let bind (s: evT env) (x: ide) (v: evT) = 
    function (i: ide) -> if (i = x) then v else (s i)
    
(* Funzione da evT a tname che associa a ogni valore il suo descrittore di tipo  *)
let getType (x: evT) : tname =
    match x with
    | Int(n) -> TInt
    | Bool(b) -> TBool
    | String(s) -> TString
    | Funval(_) -> TFun
    | RecFunval(_) -> TRecFun
    | UnBound -> TUnBound    
    
(* Type-checking *)
let typecheck ((x, y) : (tname*evT)) = 
    match x with
    | TInt -> (match y with 
               | Int(u) -> true
               | _ -> false
               )
    | TBool -> (match y with 
                | Bool(u) -> true
                | _ -> false
                )
    | TString -> (match y with
                 | String(u) -> true
                 | _ -> false
                 )
    | TFun -> (match y with
                   | Funval(i,e) -> true
                   | _ -> false
                   )
    | TRecFun -> (match y with
                   | RecFunval(i,j,e) -> true
                   | _ -> false
                   )             
    |TUnBound -> (match y with
                 | UnBound -> true
                 | _ -> false
                 )              
    
(* Errori a runtime *)
exception RuntimeError of string
  
 (* PRIMITIVE del linguaggio *)

(* Controlla se un numero è zero *)
let is_zero(x) = match (typecheck(TInt,x),x) with
    | (true, Int(v)) -> Bool(v = 0)
    | (_, _) -> raise ( RuntimeError "Wrong type")

(* Uguaglianza fra interi *)
let int_eq(x,y) =   
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v = w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Somma fra interi *)	   
let int_plus(x, y) = 
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v + w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Differenza fra interi *)
let int_sub(x, y) = 
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v - w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Prodotto fra interi *)
let int_times(x, y) =
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Int(v * w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")
    
(* Divisione fra interi *)
let int_div(x, y) =
    match(typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> 
                    if w<>0 then Int(v / w)
                            else raise (RuntimeError "Division by zero")
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Operazioni di confronto *)
let less_than(x, y) = 
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v < w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let greater_than(x, y) = 
    match (typecheck(TInt,x), typecheck(TInt,y), x, y) with
    | (true, true, Int(v), Int(w)) -> Bool(v > w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

(* Operazioni logiche *)
let bool_and(x,y) = 
    match (typecheck(TBool,x), typecheck(TBool,y), x, y) with
    | (true, true, Bool(v), Bool(w)) -> Bool(v && w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let bool_or(x,y) = 
    match (typecheck(TBool,x), typecheck(TBool,y), x, y) with
    | (true, true, Bool(v), Bool(w)) -> Bool(v || w)
    | (_,_,_,_) -> raise ( RuntimeError "Wrong type")

let bool_not(x) = 
    match (typecheck(TBool,x), x) with
    | (true, Bool(v)) -> Bool(not(v))
    | (_,_) -> raise ( RuntimeError "Wrong type");;
# Out:
# type ide = string
# type tname = TInt | TBool | TString | TFun | TRecFun | TUnBound
# type exp =
#     EInt of int
#   | CstTrue
#   | CstFalse
#   | EString of string
#   | Den of ide
#   | Sum of exp * exp
#   | Diff of exp * exp
#   | Prod of exp * exp
#   | Div of exp * exp
#   | IsZero of exp
#   | Eq of exp * exp
#   | LessThan of exp * exp
#   | GreaterThan of exp * exp
#   | And of exp * exp
#   | Or of exp * exp
#   | Not of exp
#   | IfThenElse of exp * exp * exp
#   | Let of ide * exp * exp
#   | Letrec of ide * ide * exp * exp
#   | Fun of ide * exp
#   | Apply_sd of exp * exp
# type efun = ide * exp
# type evT =
#     Int of int
#   | Bool of bool
#   | String of string
#   | UnBound
#   | Funval of efun
#   | RecFunval of ide * ide * exp
# type 't env = ide -> 't
# val emptyenv : 'a -> evT = <fun>
# val bind : evT env -> ide -> evT -> ide -> evT = <fun>
# val getType : evT -> tname = <fun>
# val typecheck : tname * evT -> bool = <fun>
# exception RuntimeError of string
# ...

# %% [markdown]
# ### Valutazione

# %%
(* Interprete con scoping dinamico *)

let rec eval_sd (e: exp) (s: evT env) : evT  =
    match e with
    | EInt(n) -> Int(n)
    | CstTrue -> Bool(true)
    | CstFalse -> Bool(false)
    | EString(s) -> String(s)
    
    (* Si valuta un identificatore cercandone il valore nell'ambiente s *)
    | Den(i) -> (s i : evT)

    (* La valutazione delle operazioni di base segue una strategia eager:
       prima di applicare l’operatore, si valutano i sottoalberi *) 
    | Prod(e1,e2) -> int_times((eval_sd e1 s), (eval_sd e2 s))
    | Sum(e1, e2) -> int_plus((eval_sd e1 s), (eval_sd e2 s))
    | Diff(e1, e2) -> int_sub((eval_sd e1 s), (eval_sd e2 s))
    | Div(e1, e2) -> int_div((eval_sd e1 s), (eval_sd e2 s))

    | IsZero(e1) -> is_zero (eval_sd e1 s) 
    | Eq(e1, e2) -> int_eq((eval_sd e1 s), (eval_sd e2 s))
    | LessThan(e1, e2) -> less_than((eval_sd e1 s),(eval_sd e2 s)) 
    | GreaterThan(e1, e2) -> greater_than((eval_sd e1 s),(eval_sd e2 s))

    | And(e1, e2) -> bool_and((eval_sd e1 s),(eval_sd e2 s))
    | Or(e1, e2) -> bool_or((eval_sd e1 s),(eval_sd e2 s)) 
    | Not(e1) -> bool_not(eval_sd e1 s)

    | IfThenElse(e1,e2,e3) -> 
    (* In questo caso la valutazione non segue una strategia eager: la valutazione 
       dei sottoalberi avviene in base alla valutazione della guardia *)
        let g = eval_sd e1 s in 
            (match (typecheck(TBool,g),g) with
            |(true, Bool(true)) -> eval_sd e2 s
            |(true, Bool(false)) -> eval_sd e3 s
            |(_,_) -> raise ( RuntimeError "Wrong type")
            )
            
  | Let(i, e1, e2) ->
      let v1 = eval_sd e1 s in
      let newenv = bind s i v1 in
      eval_sd e2 newenv
      
  | Fun(arg, ebody) ->
      Funval(arg, ebody)
      
  | Letrec(f, arg, fBody, letBody) ->
        let benv = bind (s) (f) (RecFunval(f, arg, fBody)) in
            eval_sd letBody benv    
      
  | Apply_sd(eF, eArg) ->
      let fval = eval_sd eF s in
      (match fval with
       | Funval(arg, fbody) ->
           let aVal = eval_sd eArg s in
            let aenv = bind s arg aVal in
             eval_sd fbody aenv
       | RecFunval(f, arg, fbody) ->
        let aVal = eval_sd eArg s in
        let aenv = bind s arg aVal in
        let recenv = bind aenv f fval in
        eval_sd fbody recenv      
       | _ -> failwith "Non functional value")
# Out:
# val eval_sd : exp -> evT env -> evT = <fun>

# %% [markdown]
# **Astrazione funzionale**
#
# `Fun(arg, ebody) -> Funval(arg, ebody)`
#
# Il valore esprimibile che corrisponde all’astrazione funzionale (`Funval(arg, ebody)`) contiene solo il parametro formale `arg` e il corpo della funzione dichiarata `ebody` (non serve catturare l’ambiente al momento della definizione).
#
# Il corpo della funzione verrà quindi valutato nell’ambiente in cui avviene l’applicazione, legando i parametri formali ai valori dei parametri attuali.
#
# La corrispondente regola semantica è
# $$
# \frac{}{%
#   \Sigma \triangleright \text{Fun}(arg,e_{body}) \Rightarrow FunVal(arg,e_{body})
# }
# $$

# %% [markdown]
# **Applicazione funzionale**
#
# ``| Apply_sd(eF, eArg) ->
#       let fval =  eval eF s in
#       (match fval with
#        | Funval(arg, fbody) ->
#            let aVal = eval_sd eArg s in
#            let aenv = bind s arg aVal in
#            eval fbody aenv
#        | _ -> failwith "Non functional value")``
#
#
# * si valuta `eF` nell'ambiente corrente `s`, trovando: `Funval(arg, fbody)`
# * si valuta il parametro attuale `eArg` nell’ambiente corrente `s`," cioè del chiamante, ottenendo il valore `aVal`
# * l’ambiente corrente `s` viene esteso con l’associazione tra il parametro formale `arg` e il valore `aVal`: si ottiene `aenv`
# * la funzione valuta il corpo della funzione `fbody` nell'ambiente esteso `aenv`
#
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
#   \Sigma \triangleright e_F \Rightarrow Funval(arg,f_{body})
#   \qquad
#   \Sigma \triangleright e_{Arg} \Rightarrow a_{Val}
#   \qquad
#   \Sigma[arg = a_{Val}] \triangleright f_{body} \Rightarrow v
# }{%
#   \Sigma \triangleright \text{Apply_sd}(e_F,e_{Arg}) \Rightarrow v
# }
# $$

# %% [markdown]
# **Applicazione funzionale nel caso di funzioni del primo ordine**
#
# `Apply of Den(“f”) * exp`
#
# `` | Apply_sd(Apply(Den("f"), eArg) ->
#       let fval =  s eF in
#       (match fval with
#        | Funval(arg, fbody) ->
#            let aVal = eval_sd eArg s in
#            let aenv = bind s arg aVal in
#            eval fbody aenv
#        | _ -> failwith "Non functional value")
#    | Apply_sd(_,_) -> failwith("Application: not first order function") ;;``
#
# * si recupera `Funval(arg, fbody)` dall'ambiente corrente `s`, grazie all'associazione con `eF`
# * si valuta il parametro attuale `eArg` nell’ambiente corrente `s`," cioè del chiamante, ottenendo il valore `aVal`
# * l’ambiente corrente `s` viene esteso con l’associazione tra il parametro formale `arg` e il valore `aVal`: si ottiene `aenv`
# * la funzione valuta il corpo della funzione `fbody` nell'ambiente esteso `aenv`
#
#
# La corrispondente regola semantica è
#
# $$
# \frac{%
#   \Sigma \triangleright Den(“f”) \Rightarrow Funval(arg,f_{body})
#   \qquad
#   \Sigma \triangleright e_{Arg} \Rightarrow a_{Val}
#   \qquad
#   \Sigma[arg = a_{Val}] \triangleright f_{body} \Rightarrow v
# }{%
#   \Sigma \triangleright \text{Apply_sd}(Den("f"),e_{Arg}) \Rightarrow v
# }
# $$

# %%
(* Programma: scoping dinamico *)

let prog =
  Let("x", EInt 3,                            (* x = 3 nel momento della definizione di f *)
    Let("f", Fun("y", Sum(Den "x", Den "y")), (* f(y) = x + y *)
      Let("x", EInt 5,                        (* x cambia: ora vale 5 *)
        Apply_sd(Den "f", EInt 10)             (* chiamata di f(10) *)
      )
    )
  )
# Out:
# val prog : exp =
#   Let ("x", EInt 3,
#    Let ("f", Fun ("y", Sum (Den "x", Den "y")),
#     Let ("x", EInt 5, Apply_sd (Den "f", EInt 10))))
